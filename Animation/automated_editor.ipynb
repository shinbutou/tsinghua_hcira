# %% [markdown]
# # Automated Editor

# %%
import pandas as pd
import numpy as np

# %%
file_list = ['./x_data.xlsx', './y_data.xlsx', './list_data.xlsx', './tilt_data.xlsx', './zoom_data.xlsx']
sheet_list = list(map(str, list(range(25, 62))))
x_list = ['近期任务', '桌面滑动', '父子转场'] 
y_list = ['上弹窗', '可滑动面板一', '可滑动面板二']
list_list = []
tilt_list = []
zoom_list = []
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-c0b6af00ec87> in <module>
#       1 file_list = ["./x_data.xlsx", "./y_data.xlsx", "./list_data.xlsx", "./tilt_data.xlsx", "./zoom_data.xlsx"]
#       2 sheet_list = list(map(str, list(range(25, 62))))
# ----> 3 x_list
#       4 y_list
#
# NameError: name 'x_list' is not defined

# %%
x_data = pd.read_excel('./list_data.xlsx', sheet_name='25')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-24f353c024e5> in <module>
# ----> 1 x_data = pd.read_excel('./list_data.xlsx', sheet_name='25')
#
# /opt/anaconda3/envs/thugix/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# /opt/anaconda3/envs/thugix/lib/python3.8/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     342
#     343     try:
# --> 344         data = io.parse(
#     345             sheet_name=sheet_name,
#     346             header=header,
#
# /opt/anaconda3/envs/thugix/lib/python3.8/site-packages/pandas/io/excel/_base.py in parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#    1168             DataFrame from the passed in Excel file.
#    1169         """
# -> 1170         return self._reader.parse(
#    1171             sheet_name=sheet_name,
#    1172             header=header,
#
# /opt/anaconda3/envs/thugix/lib/python3.8/site-packages/pandas/io/excel/_base.py in parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     486
#     487             if isinstance(asheetname, str):
# --> 488                 sheet = self.get_sheet_by_name(asheetname)
#     489             else:  # assume an integer if not a string
#     490                 sheet = self.get_sheet_by_index(asheetname)
#
# /opt/anaconda3/envs/thugix/lib/python3.8/site-packages/pandas/io/excel/_openpyxl.py in get_sheet_by_name(self, name)
#     499
#     500     def get_sheet_by_name(self, name: str):
# --> 501         self.raise_if_bad_sheet_by_name(name)
#     502         return self.book[name]
#     503
#
# /opt/anaconda3/envs/thugix/lib/python3.8/site-packages/pandas/io/excel/_base.py in raise_if_bad_sheet_by_name(self, name)
#     435     def raise_if_bad_sheet_by_name(self, name: str) -> None:
#     436         if name not in self.sheet_names:
# --> 437             raise ValueError(f"Worksheet named '{name}' not found")
#     438
#     439     def parse(
#
# ValueError: Worksheet named '25' not found

# %% [markdown]
# After realizing the different sheets are called with their names, instead of their sequential orders, the decision is made to just rename all the sheets.

# %%
x_data
# Out:
#    左侧右侧都会滑动退出，提醒被试注意                                         Unnamed: 1  \
# 0                NaN                                                NaN
# 1                 序号                                                 刚性
# 2                  1                                                  /
# 3                  2                                                900
# 4                  3                                                595
# 5                  4                                                640
# 6                  5                                                830
# 7                  6                                                256
# 8                  7                                                400
# 9                  8                                                695
# 10        总体感受\n（具体）  什么样的满意。什么样的不满意。用现实的比喻描述。\n背后的原因。与任务界面动画的快慢/难度/...
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         NaN        NaN        NaN        NaN
# 1          阻尼        阻尼比         时长       实际时长
# 2           /          /        350        350
# 3          60          1        337        337
# 4          39        0.8        347        347
# 5          43       0.85        346        346
# 6          52        0.9        351        351
# 7          30     0.9375        448        448
# 8          40          1        506        506
# 9          60    1.13796        506        506
# 10        NaN        NaN        NaN        NaN
#
#                                                   上弹窗  \
# 0                                               随便点哪里
# 1                                                场景 7
# 2                                         出来很快但是结尾很慢。
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6            好像有回弹，又好像没有回弹，速度比较均匀。不会突然加快速度，也不会突然减慢速度。
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  可能因为是白色，没有很大的视觉冲击，所以觉得弹一点还好。速度较慢的不好。不是闪烁一下，没有太...
#
#                                                可滑动面板一  \
# 0                                                 NaN
# 1                                                场景 8
# 2                                                 NaN
# 3                                                 NaN
# 4                                       上下回弹不好，不要一直弹。
# 5      上下弹一下还可以。回弹的时候不稳定，没有办法操作。一定要停下来才能点击操作，不然觉得不舒服。
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                     相对速度比较好，可以再快一点。
# 10  轻微回弹还好，不会太干扰信息阅读。空间位移比较短，可以时间再短一些。出现的位置不在视线的焦点...
#
#                                                可滑动面板二  Unnamed: 9  \
# 0                                                 NaN         NaN
# 1                                                场景 9         NaN
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 6                                                 NaN         NaN
# 7                                                 NaN         NaN
# 8                                                 NaN         NaN
# 9                                                 NaN         NaN
# 10  整体还可以，这个的回弹不要太大，上下弹还挺奇怪。左右晃动和生活现象对应。竖直方向的上下弹的幅...         NaN
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18
# 0           NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN
