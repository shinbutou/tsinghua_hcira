# %% [markdown]
# # Automated Editor

# %%
import pandas as pd
import numpy as np
import math

# %%
file_list = ['x', 'y', 'list', 'tilt', 'zoom']
sheet_list = list(map(str, list(range(25, 62))))
x_list = ['近期任务', '桌面滑动', '父子转场'] 
y_list = ['上弹窗', '可滑动面板一', '可滑动面板二']
list_list = ['联系人列表']
tilt_list = ['横竖屏切换']
zoom_list = ['图库', '打开应用']

# %%
x_data = pd.read_excel('./data/' + file_list[4] + '.xlsx', sheet_name='25')

# %% [markdown]
# After realizing the different sheets are called with their names, instead of their sequential orders, the decision is made to just rename all the sheets.

# %%
x_data
# Out:
#    左侧右侧都会滑动退出，提醒被试注意                                         Unnamed: 1  \
# 0                NaN                                                NaN
# 1                 序号                                                 刚性
# 2                  1                                                  /
# 3                  2                                                280
# 4                  3                                                310
# 5                  4                                                305
# 6                  5                                                285
# 7                  6                                                256
# 8                  7                                                400
# 9                  8                                                695
# 10        总体感受\n（具体）  什么样的满意。什么样的不满意。用现实的比喻描述。\n背后的原因。与任务界面动画的快慢/难度/...
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         NaN        NaN        NaN        NaN
# 1          阻尼        阻尼比         时长       实际时长
# 2         500          /        500        500
# 3          30        0.9        506        506
# 4          30       0.85        497        497
# 5          25    0.71575        438        438
# 6          27        0.8        501        501
# 7          30     0.9375        448        448
# 8          40          1        506        506
# 9          60    1.13796        506        506
# 10        NaN        NaN        NaN        NaN
#
#                                                    图库  \
# 0                                                 NaN
# 1                                                场景 1
# 2                          稍微有点慢了，前中可以再快一些。最后的时候慢了一下。
# 3                                快一些感觉比较流畅。第二个的速度更均匀。
# 4                                         回弹不是很大，还可以。
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                          快一些，没回弹，好。
# 10  可以一次成功，为什么要回弹？我并不需要回弹这个功能。不妨碍操作但是没有必要。如果没有回弹就只...
#
#                                                  打开应用  Unnamed: 8  Unnamed: 9  \
# 0                                        打开应用应当点击设置图标         NaN         NaN
# 1                                                场景 2         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                                 NaN         NaN         NaN
# 4                                                 NaN         NaN         NaN
# 5                                                 NaN         NaN         NaN
# 6                                                 NaN         NaN         NaN
# 7                                                 NaN         NaN         NaN
# 8                                                 NaN         NaN         NaN
# 9                                                 NaN         NaN         NaN
# 10  图片的回弹感受整体会更好一些。回弹太大不好。回弹和主观、感性、可爱相关。一定要快，审美属性不...         NaN         NaN
#
#     Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 15  Unnamed: 16  Unnamed: 17
# 0           NaN          NaN          NaN
# 1           NaN          NaN          NaN
# 2           NaN          NaN          NaN
# 3           NaN          NaN          NaN
# 4           NaN          NaN          NaN
# 5           NaN          NaN          NaN
# 6           NaN          NaN          NaN
# 7           NaN          NaN          NaN
# 8           NaN          NaN          NaN
# 9           NaN          NaN          NaN
# 10          NaN          NaN          NaN

# %%
if type(x_data[zoom_list[0]][2]) == str:
    print(True)
# Out:
# True

# %%
str(x_data[zoom_list[0]][5])
# Out:
# "<class 'type'>"

# %%
file = open('text.txt', 'w')
